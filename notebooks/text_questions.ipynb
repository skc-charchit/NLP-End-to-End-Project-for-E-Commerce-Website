# %% [markdown]
# # Text Cleaning & Regex Practice — Questions Only
#
# This file contains only the **questions/exercises** in Markdown (no code).
# Use this alongside the Jupyter Notebook to practice.
#
# ---
#
# ## Exercise Set 1 — Regex Extraction
#
# 📝 Your Turn: Write regex to extract phone numbers like:
# - `+91-9876543210`
# - `(123) 456-7890`
# - `9876543210`
#
# *Hint*: use `\d` for digits, and optional groups `()?` or `-?`.
#
# ---
#
# ## Exercise Set 2 — Cleaning with Pandas
#
# 📝 Your Turn: Create a DataFrame with 5 messy rows containing:
# - URLs
# - Emails
# - Numbers
#
# Then **remove both URLs and emails** using regex and create a new `cleaned_text` column.
#
# ---
#
# ## Exercise Set 3 — Token Frequency Visualization
#
# 📝 Your Turn:
# 1. Take your cleaned text column (from Set 2).
# 2. Tokenize into words (use `.split()`).
# 3. Count word frequencies.
# 4. Plot the **top 10 words**.
#
# ---
#
# ## Exercise Set 4 — Hashtags & Mentions
#
# 📝 Your Turn:
# - Create a small dataset of 5 tweets.
# - Extract hashtags and mentions into new columns.
# - Plot the **most common hashtags**.
#
# ---
#
# ## Exercise Set 5 — Stopwords & Cleaning Pipeline
#
# 📝 Your Turn:
# - Take your cleaned text column.
# - Remove stopwords.
# - Compare **top 10 words before vs after stopword removal** (make two bar charts).
#
# ---
#
# # 🚀 Next Step for You
#
# Do these exercises **in order**:
# 1. Regex → emails/phones
# 2. Cleaning text with pandas
# 3. Word frequency visualization
# 4. Hashtag/mention extraction
# 5. Stopword removal effect
#
# This covers regex, pandas cleaning, and visualization for text insights.
